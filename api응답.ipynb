# %% [markdown]
# 직접 일기 입력

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

url1 = "http://127.0.0.1:5000/analyze_emotion"
url2 = "http://127.0.0.1:5000/get_image"
sentence = input("문장을 입력해주세요: ")
data = {"sentence": sentence}

response1 = requests.post(url1, json=data)
response_data = response1.json()
print(response_data)

score = response_data.get('score', 0)
params = {'score': score}

response = requests.get(url2, params=params)

if response.status_code == 200:
    image = Image.open(BytesIO(response.content))
    plt.imshow(image)
    plt.axis('off')
    plt.show()
else:
    print('이미지를 불러오는 데 실패했습니다.')
# Out:
# {'action_recommendation': '아이스 하키', 'emotion_response': '지금이 다가 아니야. 아직 끝나지 않았어. 함께 헤쳐나가자고. 포기하지 마!', 'emotion_status': '매우 기분 안좋음', 'score': -11, 'song_recommendation': '리쌍 – 행복을 찾아서(피쳐링. 조현아 of 어반자'}

# %% [markdown]
# 일기 입력X (테스트용)
